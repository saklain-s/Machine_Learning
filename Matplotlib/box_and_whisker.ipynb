# %%
import matplotlib.pyplot as plt
x = [10,20,30,40,50,60,70,120]
plt.boxplot(x,notch=False,vert=True,widths=0.5,labels=["python"],patch_artist=True,showmeans=True,
           sym="g+",boxprops=dict(color="r"),capprops=dict(color="r"),whiskerprops=dict(color="r"),
           flierprops=dict(markeredgecolor="y"))
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16628\3567336765.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x,notch=False,vert=True,widths=0.5,labels=["python"],patch_artist=True,showmeans=True,

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40, 50, 60, 70]
x1 = [10, 20, 30, 40, 50, 60, 90]
y = [x, x1]

plt.boxplot(y, notch=False, vert=True, widths=0.5, labels=["Data 1", "Data 2"], patch_artist=True, showmeans=True,
            boxprops=dict(facecolor="lightblue"), capprops=dict(color="blue"), whiskerprops=dict(color="blue"),
            flierprops=dict(markerfacecolor="red", marker="o"))
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16628\2197206289.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(y, notch=False, vert=True, widths=0.5, labels=["Data 1", "Data 2"], patch_artist=True, showmeans=True,

# %%
char= chatgpt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 char= chatgpt
#
# NameError: name 'chatgpt' is not defined

# %%
import matplotlib.pyplot as plt

# Data
x = [10, 20, 30, 40, 50]
y = [15, 25, 35, 45, 55]

# Create basic box plot
plt.boxplot([x, y])

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
x = [10, 20, 30, 40, 50]
y = [15, 25, 35, 45, 55]

# Create horizontal box plot
plt.boxplot([x, y], vert=False)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
x = [10, 20, 30, 40, 50]
y = [15, 25, 35, 45, 55]

# Create horizontal box plot
plt.boxplot([x, y], vert=False)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
x = [10, 20, 30, 40, 50]
y = [15, 25, 35, 45, 55]

# Customizing box appearance
plt.boxplot([x, y], boxprops=dict(facecolor='lightblue', color='blue'), whiskerprops=dict(color='green'))

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 8
#       5 y = [15, 25, 35, 45, 55]
#       7 # Customizing box appearance
# ----> 8 plt.boxplot([x, y], boxprops=dict(facecolor='lightblue', color='blue'), whiskerprops=dict(color='green'))
#      10 # Show plot
#      11 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\deprecation.py:300, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     295     warn_deprecated(
#     296         since, message=f"The {old!r} parameter of {func.__name__}() "
#     297         f"has been renamed {new!r} since Matplotlib {since}; support "
#     298         f"for the old name will be dropped %(removal)s.")
#     299     kwargs[new] = kwargs.pop(old)
# --> 300 return func(*args, **kwargs)
#
# ...

# %%
import matplotlib.pyplot as plt

# Data
data = [[10, 20, 30, 40, 50],
        [15, 25, 35, 45, 55],
        [20, 30, 40, 50, 60]]

# Create grouped box plots
plt.boxplot(data, labels=['Group 1', 'Group 2', 'Group 3'])

# Show plot
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16628\3216351821.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=['Group 1', 'Group 2', 'Group 3'])

# %%
import matplotlib.pyplot as plt

# Data
data = [[10, 20, 30, 40, 50],
        [15, 25, 35, 45, 55],
        [20, 30, 40, 50, 60]]

# Create grouped box plots
plt.boxplot(data, labels=['Group 1', 'Group 2', 'Group 3'])

# Show plot
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16628\3216351821.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=['Group 1', 'Group 2', 'Group 3'])

# %%
import matplotlib.pyplot as plt

# Data
x = [10, 20, 30, 40, 50]
y = [15, 25, 35, 45, 55]

# Create box plot with mean markers
plt.boxplot([x, y], showmeans=True)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
x = [10, 20, 30, 40, 200]
y = [15, 25, 35, 45, 250]

# Create box plot with customized outlier markers
plt.boxplot([x, y], flierprops=dict(marker='o', markerfacecolor='red', markersize=10))

# Show plot
plt.show()
